# %%
import pandas as pd
import matplotlib.pyplot as plt
import ast
import seaborn as sns
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')]

# %%
df_DA_US_exploded = df_DA_US.explode('job_skills')

# %%
df_DA_US_exploded['job_posted_month'] = pd.to_datetime(df_DA_US_exploded['job_posted_date']).dt.month

# %%
df_plot = df_DA_US_exploded.pivot_table(index = 'job_posted_month',aggfunc='size',columns='job_skills',fill_value=0)

# %%
df_plot.loc['Total'] = df_plot.sum().sort_values(ascending=False)

# %%
df_plot = df_plot[df_plot.loc['Total'].sort_values(ascending=False).index]

# %%
df_plot
# Out:
# job_skills          sql  excel  tableau  python    sas      r  power bi  word  \
# job_posted_month
# 1                  4601   3592     2488    2254   1832   1513      1337   968
# 2                  3168   2587     1676    1618   1212   1045      1122   738
# 3                  3226   2661     1804    1683   1238   1141      1054   736
# 4                  3220   2549     1789    1679   1302   1038      1057   695
# 5                  2581   2118     1432    1349    972    867       860   557
# 6                  2862   2382     1628    1609    984   1017       989   721
# 7                  2609   2118     1533    1438    996    881       881   587
# 8                  3414   2731     1951    2025   1276   1271      1208   752
# 9                  2295   1801     1353    1229    856    746       820   478
# 10                 2574   1922     1429    1373    960    835       921   498
# 11                 2054   1533     1148    1049    792    647       682   430
# ...

# %%
df_plot = df_plot.reset_index()

# %%
df_plot = df_plot.set_index('job_posted_month')

# %%
df_plot
# Out:
# job_skills          sql  excel  tableau  python    sas      r  power bi  word  \
# job_posted_month
# 1                  4601   3592     2488    2254   1832   1513      1337   968
# 2                  3168   2587     1676    1618   1212   1045      1122   738
# 3                  3226   2661     1804    1683   1238   1141      1054   736
# 4                  3220   2549     1789    1679   1302   1038      1057   695
# 5                  2581   2118     1432    1349    972    867       860   557
# 6                  2862   2382     1628    1609    984   1017       989   721
# 7                  2609   2118     1533    1438    996    881       881   587
# 8                  3414   2731     1951    2025   1276   1271      1208   752
# 9                  2295   1801     1353    1229    856    746       820   478
# 10                 2574   1922     1429    1373    960    835       921   498
# 11                 2054   1533     1148    1049    792    647       682   430
# ...

# %%
df_plot = df_plot.drop('Total')

# %%
df_plot = df_plot.reset_index()

# %%
df_plot['job_posted_month'] = pd.to_datetime(df_plot['job_posted_month'],format='%m').dt.strftime('%b')

# %%
df_plot = df_plot.set_index('job_posted_month')

# %%
df_plot = df_plot.drop(columns='index')

# %%
df_plot.iloc[:,:5].plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>
