# %%
import pandas as pd
import matplotlib.pyplot as plt
import ast
import seaborn as sns
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_US = df[(df['job_country'] == 'United States')].dropna(subset='salary_year_avg')

# %%
job_titles = df_US['job_title_short'].value_counts().index[:6].to_list()
job_titles
# Out:
# ['Data Scientist',
#  'Data Analyst',
#  'Data Engineer',
#  'Senior Data Scientist',
#  'Senior Data Engineer',
#  'Senior Data Analyst']

# %%
df_US_top6 = df_US[df_US['job_title_short'].isin(job_titles)]
df_US_top6
# Out:
#        job_title_short                                          job_title  \
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# 116     Data Scientist                                     Data Scientist
# 146      Data Engineer  Data Engineer Graduate (Real Time Communicatio...
# ...                ...                                                ...
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#              job_location                                    job_via  \
# ...

# %%
job_order = df_US_top6.groupby('job_title_short')['salary_year_avg'].median().sort_values(ascending=False).index
job_order
# Out:
# Index(['Senior Data Scientist', 'Senior Data Engineer', 'Data Scientist',
#        'Data Engineer', 'Senior Data Analyst', 'Data Analyst'],
#       dtype='object', name='job_title_short')

# %%
sns.boxplot(data=df_US_top6,x='salary_year_avg',y='job_title_short',order=job_order)
sns.despine()
sns.set_theme(style="ticks")
plt.ylabel('')
plt.xlabel('')
plt.title('Median Salary distribution od Top 6 Jobs in US')
plt.xlim(0,600000)
ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter (lambda y,pos: f'${int(y/1000)}k'))
plt.show()

# %%
df_US_DA = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()

# %%
df_US_DA= df_US_DA.dropna(subset=['salary_year_avg'])

# %%
df_US_DA = df_US_DA.explode('job_skills')

# %%
job_skills =df_US_DA['job_skills'].value_counts().to_frame(name='count').head(10)
job_skills['median'] = df_US_DA.groupby('job_skills')['salary_year_avg'].median()

# %%
job_skills = job_skills.sort_values(by='median',ascending= False)
job_skills
# Out:
#             count    median
# job_skills
# python       1431  97500.00
# tableau      1364  92875.00
# r             893  92500.00
# sql server    286  92500.00
# sql          2508  91000.00
# sas           926  90000.00
# power bi      838  90000.00
# powerpoint    462  85000.00
# excel        1808  84392.00
# word          461  81194.75

# %%
df_Top_pay = df_US_DA.groupby('job_skills')['salary_year_avg'].median().sort_values(ascending=False).to_frame(name='median')

# %%
df_Top_pay = df_Top_pay.head(10)
df_Top_pay
# Out:
#                 median
# job_skills
# dplyr         196250.0
# bitbucket     189000.0
# gitlab        186000.0
# solidity      179000.0
# hugging face  175000.0
# couchbase     160515.0
# ansible       159640.0
# mxnet         149000.0
# cassandra     148250.0
# vmware        147500.0

# %%
fig,ax = plt.subplots(2,1)
sns.set_theme(style='ticks')
sns.despine()
plt.tight_layout(h_pad=2)
sns.barplot(data=df_Top_pay,x='median',y=df_Top_pay.index,ax=ax[0],hue='median',legend=False)
ax[0].set_title('Highest paying skills for Data Analysts in the US')
ax[0].set_xlabel('')
ax[0].set_ylabel('')
ax[0].set_xlim(0,200000)
sns.barplot(data=job_skills,x='median',y=job_skills.index,ax=ax[1],hue='median',legend=False)
ax[1].set_title('Most Demand skills for Data Analysts in the US')
ax[1].set_xlabel('Median Salary in ($)')
ax[1].set_ylabel('')
ax[1].set_xlim(0,200000)
# Out:
# (0.0, 200000.0)
